# %% [markdown]
# # VLSI - Assignment 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from scipy.spatial import distance
from scipy.optimize import fsolve

# %% [markdown]
# ## Write Margin

# %%
# Load data
df = pd.read_csv('data/wm_nofloat.csv')

sim_nofloat = {
    "vdd=0.3": {},
    "vdd=0.4": {},
    "vdd=0.5": {},
    "vdd=0.6": {},
    "vdd=0.7": {},
    "vdd=0.8": {},
    "vdd=0.9": {},
    "vdd=1.0": {},
    "vdd=1.1": {},
    "vdd=1.2": {}
}

for col in df.columns:
    if 'VDD=3.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=0.3"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=4.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=0.4"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=5.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=0.5"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=6.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=0.6"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=7.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=0.7"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=8.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=0.8"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=9.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=0.9"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.00e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=1.0"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.10e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=1.1"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.20e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_nofloat["vdd=1.2"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')

# Load data
df = pd.read_csv('data/wm_float.csv')

sim_float = {
    "vdd=0.3": {},
    "vdd=0.4": {},
    "vdd=0.5": {},
    "vdd=0.6": {},
    "vdd=0.7": {},
    "vdd=0.8": {},
    "vdd=0.9": {},
    "vdd=1.0": {},
    "vdd=1.1": {},
    "vdd=1.2": {}
}

for col in df.columns:
    if 'VDD=3.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=0.3"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=4.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=0.4"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=5.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=0.5"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=6.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=0.6"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=7.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=0.7"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=8.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=0.8"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=9.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=0.9"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.00e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=1.0"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.10e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=1.1"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.20e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim_float["vdd=1.2"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')

# %%
## Params
# Linewidth
lw = 3

vdd = '1.2'
fig, ax = plt.subplots(2, 1, figsize=(8, 6), sharex=False)
data = sim_nofloat[f'vdd={vdd}']

t_start = 3e-6
t_end   = 4e-6

mask    = (data['WL X'] >= t_start) & (data['WL X'] <= t_end)
time    = data['WL X'][mask]
wl      = data['WL Y'][mask]
q       = data['Q Y'][mask]
qb      = data['QB Y'][mask]

ax[0].plot(wl, q, label='Q', color='black', linewidth=lw)
ax[0].plot(wl, qb, label='QB', color='black', linewidth=lw, linestyle='--', alpha=0.5)

condition_mask  = (q < float(vdd) * 0.1) & (qb > float(vdd) * 0.9)
indices         = np.where(condition_mask)[0]
if len(indices) == 0:
    wm_nofloat_tot  = 0
    wm_nofloat      = 0
else:
    wm_nofloat_tot  = wl[indices[0]]
    wm_nofloat      = float(vdd) - wm_nofloat_tot

ax[0].text(wm_nofloat_tot + float(vdd)/50, float(vdd)/2, f"WM = {wm_nofloat:.2f} V",
         fontsize=10,
         ha='left',
         va='bottom',
         color='black',
         bbox=dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='white', linewidth=1))

# Floating

data = sim_float[f'vdd={vdd}']

t_start = 3e-6
t_end   = 3.1e-6

mask    = (data['WL X'] >= t_start) & (data['WL X'] <= t_end)
time    = data['WL X'][mask]
wl      = data['WL Y'][mask]
q       = data['Q Y'][mask]
qb      = data['QB Y'][mask]

ax[1].plot(wl, q, label='Q', color='black', linewidth=lw)
ax[1].plot(wl, qb, label='QB', color='black', linewidth=lw, linestyle='--', alpha=0.5)

condition_mask  = (q < float(vdd) * 0.1) & (qb > float(vdd) * 0.9)
indices         = np.where(condition_mask)[0]
if len(indices) == 0:
    wm_float_tot  = 0
    wm_float      = 0
else:
    wm_float_tot  = wl[indices[0]]
    wm_float      = float(vdd) - wm_float_tot

ax[1].text(wm_float_tot + float(vdd)/50, float(vdd)/2, f"WM = {wm_float:.2f} V",
         fontsize=10,
         ha='left',
         va='bottom',
         color='black',
         bbox=dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='white', linewidth=1))

for i in range(0, 2):
    #ax[i].set_xticks(np.arange(0, 20e-6, 2e-6))
    ax[i].set_xlim(0, float(vdd) + 0.05)
    ax[i].set_xlabel('WL [V]')
    ax[i].set_ylim(-0.05, float(vdd) + 0.05)
    ax[i].set_yticks([0, float(vdd)])
    ax[i].set_yticklabels(['0V', 'VDD'])
    ax[i].legend(loc='upper right')

ax[0].set_title(f'Standard Write (No Floating Supply)')
ax[1].set_title(f'Improved Write (Floating Supply)')
fig.tight_layout()

fig.savefig(f'../assignment_1/sram_wm_{vdd}.svg')

# %% [markdown]
# ## Read/Write Transient
#
# Plot results from transient simulation.
#
# - $L_{NMOS} = 60 \text{n}$
# - $W_{NMOS} = 120 \text{n}$
# - $L_{PMOS} = 60 \text{n}$
# - $W_{PMOS} = 240 \text{n}$

# %%
# Load data
df = pd.read_csv('data/ass1_sram_tran.csv')

sim = {
    "vdd=0.3": {},
    "vdd=0.4": {},
    "vdd=0.5": {},
    "vdd=0.6": {},
}

for col in df.columns:
    if 'VDD=3.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.3"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=4.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.4"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=5.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.5"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=6.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.6"][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')

# %%
## Params
# Linewidth
lw = 3

vdd = '0.3'
fig, ax = plt.subplots(5, 1, figsize=(8, 6), sharex=True)
data = sim[f'vdd={vdd}']

ax[0].plot(data['WL X'], data['WL Y'], label='WL', color='black', linewidth=lw)

ax[1].plot(data['BL X'], data['BL Y'], label='BL', color='black', linewidth=lw, alpha=0.5)
ax[1].plot(data['BLB X'], data['BLB Y'], label='BLB', color='black', linewidth=lw, linestyle='--')

ax[2].plot(data['Q X'], data['Q Y'], label='Q', color='black', linewidth=lw, alpha=0.5)
ax[2].plot(data['QB X'], data['QB Y'], label='QB', color='black', linewidth=lw, linestyle='--')

ax[3].plot(data['VDDONB X'], data['VDDONB Y'], label='VDDONB', color='black', linewidth=lw, alpha=0.5)
ax[3].plot(data['VVDD X'], data['VVDD Y'], label='VVDD', color='black', linewidth=lw, linestyle='--')

ax[4].plot(data['RWL X'], data['RWL Y'], label='RWL', color='black', linewidth=lw, alpha=0.5)
ax[4].plot(data['RBL X'], data['RBL Y'], label='RBL', color='black', linewidth=lw, linestyle='--')

for i in range(0, 5):
    ax[i].set_xticks(np.arange(0, 20e-6, 2e-6))
    ax[i].set_xlim(0, 20e-6)
    ax[i].set_xlabel('Time (s)')
    ax[i].set_ylim(-0.05, float(vdd) + 0.05)
    ax[i].set_yticks([0, float(vdd)])
    ax[i].set_yticklabels(['0V', 'VDD'])
    ax[i].legend(loc='upper right')

ax[0].set_title(f'Write and Read (VDD={vdd}V)')
fig.tight_layout()

# fig.savefig(f'../assignment_1/report/images/sram_vdd_{vdd}.svg')

# %%
## Params
# Linewidth
lw = 3

vdd = '0.4'
fig, ax = plt.subplots(5, 1, figsize=(8, 6), sharex=True)
data = sim[f'vdd={vdd}']

ax[0].plot(data['WL X'], data['WL Y'], label='WL', color='black', linewidth=lw)

ax[1].plot(data['BL X'], data['BL Y'], label='BL', color='black', linewidth=lw, alpha=0.5)
ax[1].plot(data['BLB X'], data['BLB Y'], label='BLB', color='black', linewidth=lw, linestyle='--')

ax[2].plot(data['Q X'], data['Q Y'], label='Q', color='black', linewidth=lw, alpha=0.5)
ax[2].plot(data['QB X'], data['QB Y'], label='QB', color='black', linewidth=lw, linestyle='--')

ax[3].plot(data['VDDONB X'], data['VDDONB Y'], label='VDDONB', color='black', linewidth=lw, alpha=0.5)
ax[3].plot(data['VVDD X'], data['VVDD Y'], label='VVDD', color='black', linewidth=lw, linestyle='--')

ax[4].plot(data['RWL X'], data['RWL Y'], label='RWL', color='black', linewidth=lw, alpha=0.5)
ax[4].plot(data['RBL X'], data['RBL Y'], label='RBL', color='black', linewidth=lw, linestyle='--')

for i in range(0, 5):
    ax[i].set_xticks(np.arange(0, 20e-6, 2e-6))
    ax[i].set_xlim(0, 20e-6)
    ax[i].set_xlabel('Time (s)')
    ax[i].set_ylim(-0.05, float(vdd) + 0.05)
    ax[i].set_yticks([0, float(vdd)])
    ax[i].set_yticklabels(['0V', 'VDD'])
    ax[i].legend(loc='upper right')

ax[0].set_title(f'Write and Read (VDD={vdd}V)')
fig.tight_layout()

# fig.savefig(f'../assignment_1/report/images/sram_vdd_{vdd}.svg')

# %%
## Params
# Linewidth
lw = 3

vdd = '0.5'
fig, ax = plt.subplots(5, 1, figsize=(8, 6), sharex=True)
data = sim[f'vdd={vdd}']

ax[0].plot(data['WL X'], data['WL Y'], label='WL', color='black', linewidth=lw)

ax[1].plot(data['BL X'], data['BL Y'], label='BL', color='black', linewidth=lw, alpha=0.5)
ax[1].plot(data['BLB X'], data['BLB Y'], label='BLB', color='black', linewidth=lw, linestyle='--')

ax[2].plot(data['Q X'], data['Q Y'], label='Q', color='black', linewidth=lw, alpha=0.5)
ax[2].plot(data['QB X'], data['QB Y'], label='QB', color='black', linewidth=lw, linestyle='--')

ax[3].plot(data['VDDONB X'], data['VDDONB Y'], label='VDDONB', color='black', linewidth=lw, alpha=0.5)
ax[3].plot(data['VVDD X'], data['VVDD Y'], label='VVDD', color='black', linewidth=lw, linestyle='--')

ax[4].plot(data['RWL X'], data['RWL Y'], label='RWL', color='black', linewidth=lw, alpha=0.5)
ax[4].plot(data['RBL X'], data['RBL Y'], label='RBL', color='black', linewidth=lw, linestyle='--')

for i in range(0, 5):
    ax[i].set_xticks(np.arange(0, 20e-6, 2e-6))
    ax[i].set_xlim(0, 20e-6)
    ax[i].set_xlabel('Time (s)')
    ax[i].set_ylim(-0.05, float(vdd) + 0.05)
    ax[i].set_yticks([0, float(vdd)])
    ax[i].set_yticklabels(['0V', 'VDD'])
    ax[i].legend(loc='upper right')

ax[0].set_title(f'Write and Read (VDD={vdd}V)')
fig.tight_layout()

# fig.savefig(f'../assignment_1/report/images/sram_vdd_{vdd}.svg')

# %%
## Params
# Linewidth
lw = 3

vdd = '0.6'
fig, ax = plt.subplots(5, 1, figsize=(8, 6), sharex=True)
data = sim[f'vdd={vdd}']

ax[0].plot(data['WL X'], data['WL Y'], label='WL', color='black', linewidth=lw)

ax[1].plot(data['BL X'], data['BL Y'], label='BL', color='black', linewidth=lw, alpha=0.5)
ax[1].plot(data['BLB X'], data['BLB Y'], label='BLB', color='black', linewidth=lw, linestyle='--')

ax[2].plot(data['Q X'], data['Q Y'], label='Q', color='black', linewidth=lw, alpha=0.5)
ax[2].plot(data['QB X'], data['QB Y'], label='QB', color='black', linewidth=lw, linestyle='--')

ax[3].plot(data['VDDONB X'], data['VDDONB Y'], label='VDDONB', color='black', linewidth=lw, alpha=0.5)
ax[3].plot(data['VVDD X'], data['VVDD Y'], label='VVDD', color='black', linewidth=lw, linestyle='--')

ax[4].plot(data['RWL X'], data['RWL Y'], label='RWL', color='black', linewidth=lw, alpha=0.5)
ax[4].plot(data['RBL X'], data['RBL Y'], label='RBL', color='black', linewidth=lw, linestyle='--')

for i in range(0, 5):
    ax[i].set_xticks(np.arange(0, 20e-6, 2e-6))
    ax[i].set_xlim(0, 20e-6)
    ax[i].set_xlabel('Time (s)')
    ax[i].set_ylim(-0.05, float(vdd) + 0.05)
    ax[i].set_yticks([0, float(vdd)])
    ax[i].set_yticklabels(['0V', 'VDD'])
    ax[i].legend(loc='upper right')

ax[0].set_title(f'Write and Read (VDD={vdd}V)')
fig.tight_layout()

# fig.savefig(f'../assignment_1/report/images/sram_vdd_{vdd}.svg')

# %% [markdown]
# ## Butterfly 10T and 6T

# %%
# Load data
df = pd.read_csv('data/ass1_sram_butterfly.csv')

sim = {
    "vdd=0.3": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.4": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.5": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.6": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.7": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.8": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.9": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.0": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.1": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.2": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
}

for col in df.columns:
    if 'nom' in col:
        model_lib = 'tt'
    if 'ff_lib' in col:
        model_lib = 'ff'
    if 'ss_lib' in col:
        model_lib = 'ss'
    if 'sf_lib' in col:
        model_lib = 'sf'
    if 'fs_lib' in col:
        model_lib = 'fs'
    if 'VDD=3.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.3"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=4.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.4"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=5.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.5"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=6.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.6"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=7.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.7"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=8.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.8"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=9.00e-01' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=0.9"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.00e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=1.0"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.10e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=1.1"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')
    if 'VDD=1.20e+00' in col:
        col_name = col.split(' ')[0] + ' ' + col.split(' ')[2]
        sim["vdd=1.2"][model_lib][col_name] = pd.to_numeric(df[col].tolist(), errors='coerce')

# %%
## Shitty ass slow as shit chatgpt function i can't be bothered
def find_intersection(x1, y1, x2, y2):
    """ Finds intersection points of (x1, y1) with (x2, y2) """
    intersection_x = []
    intersection_y = []
    
    for i in range(len(x1) - 1):
        for j in range(len(x2) - 1):
            # Line segment 1 (x1[i], y1[i]) to (x1[i+1], y1[i+1])
            # Line segment 2 (x2[j], y2[j]) to (x2[j+1], y2[j+1])
            A = np.array([[x1[i+1] - x1[i], -(x2[j+1] - x2[j])],
                          [y1[i+1] - y1[i], -(y2[j+1] - y2[j])]])
            B = np.array([x2[j] - x1[i], y2[j] - y1[i]])
            
            if np.linalg.det(A) != 0:  # Check if lines are not parallel
                t, s = np.linalg.solve(A, B)
                if 0 <= t <= 1 and 0 <= s <= 1:
                    inter_x = x1[i] + t * (x1[i+1] - x1[i])
                    inter_y = y1[i] + t * (y1[i+1] - y1[i])
                    intersection_x.append(inter_x)
                    intersection_y.append(inter_y)
                    
    return intersection_x, intersection_y

# %%
## Params
# Linewidth
lw = 3

vdd = '0.3'
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
data = sim[f'vdd={vdd}']['tt']
data = pd.DataFrame(data)

valid_indices = (data['QH_6T X'] >= 0) & (data['QH_6T X'] <= float(vdd))
data = data[valid_indices]

ax.plot(data[f'QH_6T Y'], data[f'QBH_6T Y'], label='6T', color='black', alpha=0.5, linewidth=lw, linestyle='-')
ax.plot(data[f'QBH_6T Y'], data[f'QH_6T Y'], label='', color='black', alpha=0.5, linewidth=lw, linestyle='-')
ax.plot(data[f'QH_10T Y'], data[f'QBH_10T Y'], label='10T', color='black', linewidth=lw, linestyle='--')
ax.plot(data[f'QBH_10T Y'], data[f'QH_10T Y'], label='', color='black', linewidth=lw, linestyle='--')

ax.set_title(f'Hold SNM (VDD={vdd}V)')
ax.legend(loc='upper right')
ax.set_xlim(0, float(vdd))
ax.set_ylim(0, float(vdd))
fig.tight_layout()

fig.savefig(f'../assignment_1/report/images/butterfly_hold_{vdd}.svg')

# %%
## Params
# Linewidth
lw = 3

vdd = '0.3'
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
data = sim[f'vdd={vdd}']['tt']
data = pd.DataFrame(data)

# Input 6T or 10T here
circuit = '6T'

# Input 'R' or 'H'
read = 'R'

valid_indices = (data['QH_6T X'] >= 0) & (data['QH_6T X'] <= float(vdd))
data = data[valid_indices]

ax.plot(data[f'Q{read}_{circuit} Y'], data[f'QB{read}_{circuit} Y'], label='10T', color='black', linewidth=lw, linestyle='--')
ax.plot(data[f'QB{read}_{circuit} Y'], data[f'Q{read}_{circuit} Y'], label='', color='black', linewidth=lw, linestyle='--')

max_dist = 0
inter = {
    'inter_x_lower': 0,
    'inter_y_lower': 0,
    'inter_x_upper': 0,
    'inter_y_upper': 0,
}
for i in np.arange(0, 1, 0.1):
    x = data['QR_6T Y']
    y = data['QR_6T Y']
    y = [y + i for y in y]
    inter_x_upper, inter_y_upper = find_intersection(x, y, data[f'Q{read}_{circuit} Y'], data[f'QB{read}_{circuit} Y'])
    inter_x_lower, inter_y_lower = find_intersection(x, y, data[f'QB{read}_{circuit} Y'], data[f'Q{read}_{circuit} Y'])
    if len(inter_x_upper) == 0 or len(inter_x_lower) == 0:
        continue
    dist = np.sqrt((inter_x_upper[0] - inter_x_lower[0]) ** 2 + (inter_y_upper[0] - inter_y_lower[0]) ** 2)
    if dist > max_dist:
        max_dist = dist
        inter['inter_x_lower'] = inter_x_lower[0]
        inter['inter_y_lower'] = inter_y_lower[0]
        inter['inter_x_upper'] = inter_x_upper[0]
        inter['inter_y_upper'] = inter_y_upper[0]

hor_dist = np.sqrt(max_dist**2/2)

rect = Rectangle((inter['inter_x_lower'], inter['inter_y_lower']), hor_dist, hor_dist, linewidth=1, edgecolor='black', facecolor='none')
ax.add_patch(rect)
print(hor_dist)

if read == 'R':
    title = "Read SNM"
else:
    title = "Hold SNM"
ax.set_title(f'{title} (VDD={vdd}V)')
ax.legend(loc='upper right')
ax.set_xlim(0, float(vdd))
ax.set_ylim(0, float(vdd))
fig.tight_layout()

# fig.savefig(f'../assignment_1/report/images/sram_vdd_{vdd}.svg')

# %%
## Params
# Linewidth
lw = 3

vdd_list = ['1.2', '1.1', '1.0', '0.9', '0.8', '0.7', '0.6', '0.5', '0.4', '0.3']

# Input 6T or 10T here
circuit = '6T'

# Input 'R' or 'H'
read = 'R'

r_6t_snm = {
    "vdd=0.3": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.4": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.5": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.6": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.7": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.8": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.9": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.0": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.1": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.2": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
}

for vdd in vdd_list:
    for key in sim[f'vdd={vdd}'].keys():
        data = sim[f'vdd={vdd}'][key]
        data = pd.DataFrame(data)

        valid_indices = (data['QH_6T X'] >= 0) & (data['QH_6T X'] <= float(vdd))
        data = data[valid_indices]

        max_dist = 0
        inter = {
            'inter_x_lower': 0,
            'inter_y_lower': 0,
            'inter_x_upper': 0,
            'inter_y_upper': 0,
        }
        for i in np.arange(0, 1, 0.1):
            x = data['QR_6T Y']
            y = data['QR_6T Y']
            y = [y + i for y in y]
            inter_x_upper, inter_y_upper = find_intersection(x, y, data[f'Q{read}_{circuit} Y'], data[f'QB{read}_{circuit} Y'])
            inter_x_lower, inter_y_lower = find_intersection(x, y, data[f'QB{read}_{circuit} Y'], data[f'Q{read}_{circuit} Y'])
            if len(inter_x_upper) == 0 or len(inter_x_lower) == 0:
                continue
            dist = np.sqrt((inter_x_upper[0] - inter_x_lower[0]) ** 2 + (inter_y_upper[0] - inter_y_lower[0]) ** 2)
            if dist > max_dist:
                max_dist = dist
                inter['inter_x_lower'] = inter_x_lower[0]
                inter['inter_y_lower'] = inter_y_lower[0]
                inter['inter_x_upper'] = inter_x_upper[0]
                inter['inter_y_upper'] = inter_y_upper[0]

        hor_dist = np.sqrt(max_dist**2/2)
        r_6t_snm[f'vdd={vdd}'][key] = hor_dist

# %%
## Params
# Linewidth
lw = 3

vdd_list = ['1.2', '1.1', '1.0', '0.9', '0.8', '0.7', '0.6', '0.5', '0.4', '0.3']

# Input 6T or 10T here
circuit = '10T'

# Input 'R' or 'H'
read = 'R'

r_10t_snm = {
    "vdd=0.3": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.4": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.5": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.6": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.7": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.8": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=0.9": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.0": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.1": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
    "vdd=1.2": {'tt': {}, 'ff': {}, 'ss': {}, 'sf': {}, 'fs': {}},
}

for vdd in vdd_list:
    for key in sim[f'vdd={vdd}'].keys():
        data = sim[f'vdd={vdd}'][key]
        data = pd.DataFrame(data)

        valid_indices = (data['QH_6T X'] >= 0) & (data['QH_6T X'] <= float(vdd))
        data = data[valid_indices]

        max_dist = 0
        inter = {
            'inter_x_lower': 0,
            'inter_y_lower': 0,
            'inter_x_upper': 0,
            'inter_y_upper': 0,
        }
        for i in np.arange(0, 1, 0.1):
            x = data['QR_6T Y']
            y = data['QR_6T Y']
            y = [y + i for y in y]
            inter_x_upper, inter_y_upper = find_intersection(x, y, data[f'Q{read}_{circuit} Y'], data[f'QB{read}_{circuit} Y'])
            inter_x_lower, inter_y_lower = find_intersection(x, y, data[f'QB{read}_{circuit} Y'], data[f'Q{read}_{circuit} Y'])
            if len(inter_x_upper) == 0 or len(inter_x_lower) == 0:
                continue
            dist = np.sqrt((inter_x_upper[0] - inter_x_lower[0]) ** 2 + (inter_y_upper[0] - inter_y_lower[0]) ** 2)
            if dist > max_dist:
                max_dist = dist
                inter['inter_x_lower'] = inter_x_lower[0]
                inter['inter_y_lower'] = inter_y_lower[0]
                inter['inter_x_upper'] = inter_x_upper[0]
                inter['inter_y_upper'] = inter_y_upper[0]

        hor_dist = np.sqrt(max_dist**2/2)
        r_10t_snm[f'vdd={vdd}'][key] = hor_dist

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))

vdd = [1.2, 1.1, 1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3]

sorted_keys = sorted(r_6t_snm.keys(), reverse=True)

lw = 2
ax.plot(vdd, [r_6t_snm[key]['tt'] for key in sorted_keys], label='6T TT', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='o', markersize=8)
ax.plot(vdd, [r_6t_snm[key]['ff'] for key in sorted_keys], label='6T FF', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='s', markersize=8)
ax.plot(vdd, [r_6t_snm[key]['ss'] for key in sorted_keys], label='6T SS', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='^', markersize=8)
ax.plot(vdd, [r_6t_snm[key]['sf'] for key in sorted_keys], label='6T SF', color='black', linewidth=lw, alpha = 1, linestyle='--', marker='d', markersize=8)
ax.plot(vdd, [r_6t_snm[key]['fs'] for key in sorted_keys], label='6T FS', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='x', markersize=8)
ax.legend(loc='upper left')
ax.set_xlabel('VDD (V)')
ax.set_ylabel('SNM')
ax.set_xticks(np.arange(0.3, 1.3, 0.1))
ax.set_yticks(np.arange(0, 0.3, 0.05))

fig.tight_layout()
fig.savefig(f'../assignment_1/report/images/6t_snm.svg')

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))

vdd = [1.2, 1.1, 1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3]

sorted_keys = sorted(r_10t_snm.keys(), reverse=True)

lw = 2
ax.plot(vdd, [r_10t_snm[key]['tt'] for key in sorted_keys], label='10T TT', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='o', markersize=8)
ax.plot(vdd, [r_10t_snm[key]['ff'] for key in sorted_keys], label='10T FF', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='s', markersize=8)
ax.plot(vdd, [r_10t_snm[key]['ss'] for key in sorted_keys], label='10T SS', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='^', markersize=8)
ax.plot(vdd, [r_10t_snm[key]['sf'] for key in sorted_keys], label='10T SF', color='black', linewidth=lw, alpha = 1, linestyle='--', marker='d', markersize=8)
ax.plot(vdd, [r_10t_snm[key]['fs'] for key in sorted_keys], label='10T FS', color='black', linewidth=lw, alpha = 1, linestyle='-', marker='x', markersize=8)
ax.legend(loc='upper left')
ax.set_xlabel('VDD (V)')
ax.set_ylabel('SNM')
ax.set_xticks(np.arange(0.3, 1.3, 0.1))
ax.set_yticks(np.arange(0, 0.6, 0.05))

fig.tight_layout()
fig.savefig(f'../assignment_1/report/images/10t_snm.svg')
